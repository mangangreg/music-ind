# %% [markdown]
# # Imports

# %%
import sys
import json
import sqlite3
from pathlib import Path

import pandas as pd
from sqlalchemy import create_engine

root = '../..' 
sys.path.append(root)
from src.tools import paths
from src.tools import data_tools as dt
from src.tools import scrape_tools as st

# %% [markdown]
# # SQLITE

# %%
conn = sqlite3.connect('music-data.db')

# %%
c = conn.cursor()

# %%
c.execute('CREATE TABLE STONKS (date VARCHAR(10), name VARCHAR(10), price INT(10))')

# %%
c.execute("INSERT INTO stoNks VALUES ('2020/01/01', 'AAPL', 400),('2020/01/07', 'AMZN', 1200)")

# %%
conn.commit()

# %%
c.execute("SELECT * from STONKS")

# %%
c.fetchall()
# Out:
# [('2020/01/01', 'AAPL', 400), ('2020/01/07', 'AMZN', 1200)]

# %%
pd.read_sql_query('select * from stonks',conn)
# Out:
#          date  name  price
# 0  2020/01/01  AAPL    400
# 1  2020/01/07  AMZN   1200

# %% [markdown]
# # SQL Alchemy

# %%
engine = create_engine('sqlite:////mnt/c/Users/Greg Mangan/code/music-ind/music-data2.db', echo=False)

# %%
from sqlalchemy.ext.declarative import declarative_base

Base = declarative_base()

# %% [markdown]
# ## Songs table

# %%
from sqlalchemy import Column, Integer, String
class Song(Base):
    __tablename__ = 'songs'
    __table_args__ = {'extend_existing': True}
    
    id = Column(String, primary_key=True)
    title = Column(String)
    url = Column(String)
    release_date = Column(String)
    genres = Column(String)
    
    def __repr__(self):
        return f"<Song(title='{self.title}' url='{self.url}')"

# %%
Base.metadata.create_all(engine)

# %%
from sqlalchemy.orm import sessionmaker

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
session.add(bbp)
session.commit()

# %%
t1 = session.query(Song).first()
print(t1)
# Out:
# <Song(title='boom boom pow.mp3' url='/wiki/Boom_Boom_Pow')

# %%
song_paths = list(paths.SONGS.glob('*.json'))
# Out:
# [PosixPath('/mnt/c/Users/Greg Mangan/code/music-ind/data/songs/0005648762.json'),
#  PosixPath('/mnt/c/Users/Greg Mangan/code/music-ind/data/songs/0009def3d2.json'),
#  PosixPath('/mnt/c/Users/Greg Mangan/code/music-ind/data/songs/001224dc29.json'),
#  PosixPath('/mnt/c/Users/Greg Mangan/code/music-ind/data/songs/001536cb88.json'),
#  PosixPath('/mnt/c/Users/Greg Mangan/code/music-ind/data/songs/001a98d73b.json')]

# %%
json.load(open(song_paths[0]))
# Out:
# {'id': '0005648762',
#  'title': 'Kiss on My List',
#  'url': '/wiki/Kiss_on_My_List',
#  'artists': [{'name': 'Hall & Oates',
#    'url': '/wiki/Hall_%26_Oates',
#    'order': 0}],
#  'release_date': 'January 24, 1981',
#  'genres': ['Pop rock', 'blue-eyed soul'],
#  'length': '4:25 (album version)  3:48 (45 version)',
#  'songwriters': [{'name': 'Daryl Hall', 'url': '/wiki/Daryl_Hall', 'order': 0},
#   {'name': 'Janna Allen', 'url': '/wiki/Janna_Allen', 'order': 1}],
#  'producers': [{'name': 'Daryl Hall', 'url': '/wiki/Daryl_Hall', 'order': 0},
#   {'name': 'John Oates', 'url': '/wiki/John_Oates', 'order': 1}]}

# %%
smap = lambda d: {
    'id' : d['id'],
    'title': d['title'],
    'release_date': d.get('release_date',''),
    'genres': ",".join(d.get('genres',[])),
    'url': d['url']
}

# %%
for spath in song_paths:
    
    session.add(Song(**smap(json.load(open(spath)))),)
session.commit()

# %%
pd.read_sql_table('songs',engine)
# Out:
#               id                                       title  \
# 0     0005648762                             Kiss on My List
# 1     0009def3d2                                      Sherry
# 2     001224dc29                      Why Can't This Be Love
# 3     001536cb88  I'm Gonna Love You Just a Little More Baby
# 4     001a98d73b                              Telephone Line
# ...          ...                                         ...
# 4743  ffd46eaabc                                        Sara
# 4744  ffd689119d                     I Can't Get Next to You
# 4745  ffdc78eafb                              Sexual Healing
# 4746  ffe5348ef0                              MacArthur Park
# 4747  ffe721d2e2                             I Wanna Be Down
#
#                                                     url  \
# 0                                 /wiki/Kiss_on_My_List
# 1                                   /wiki/Sherry_(song)
# 2                        /wiki/Why_Can%27t_This_Be_Love
# 3     /wiki/I%27m_Gonna_Love_You_Just_a_Little_More_...
# 4                           /wiki/Telephone_Line_(song)
# ...                                                 ...
# 4743                    /wiki/Sara_(Fleetwood_Mac_song)
# 4744                    /wiki/I_Can%27t_Get_Next_to_You
# 4745                               /wiki/Sexual_Healing
# 4746                        /wiki/MacArthur_Park_(song)
# 4747                              /wiki/I_Wanna_Be_Down
#
#                         release_date  \
# 0                   January 24, 1981
# 1                        August 1962
# 2                  February 26, 1986
# 3                         April 1973
# 4      21 May 1977 (UK)May 1977 (US)
# ...                              ...
# 4743                 5 December 1979
# 4744                   July 30, 1969
# 4745                     1982 (1982)
# 4746                      April 1968
# 4747  September 6, 1994 (1994-09-06)
#
#                                                  genres
# 0                               Pop rock,blue-eyed soul
# 1                                 Rock and roll,doo-wop
# 2
# 3                                             Disco,R&B
# 4                           Progressive pop,,soft rock,
# ...                                                 ...
# 4743
# 4744                              Funk,psychedelic soul
# 4745                               Post-disco,soul,funk
# 4746  Baroque pop,orchestral pop,psychedelic pop,pro...
# 4747                               R&B,pop,hip hop soul
#
# [4748 rows x 5 columns]

# %% [markdown]
# ## People table

# %%
class Person(Base):
    __tablename__ = 'people'
    __table_args__ = {'extend_existing': True}
    
    id = Column(Integer,primary_key=True)
    song_id = Column(String)
    ptype = Column(String)
    name = Column(String)
    url = Column(String)
    order = Column(String)
    
    def __repr__(self):
        return f"<Person(name='{self.name}' type='{self.ptype}')"
# Out:
# /home/greg/.local/lib/python3.8/site-packages/sqlalchemy/ext/declarative/clsregistry.py:125: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.Person, and will be replaced in the string-lookup table.
#   util.warn(

# %%
Person.__table__.create(bind=engine)

# %%
def pmap(d):
    ''' Map a song dictionary to a list of people'''
    song_id = d['id']
    res = []
    
    for ptype in ['artists', 'songwriters', 'producers']:
        for person in d.get(ptype,[]):
            res.append({
                'song_id': song_id,
                'ptype': ptype.rstrip('s'),
                'name': person.get('name',''),
                'url': person.get('url',''),
                'order':person.get('ordrer','')
            })
    return res

# %%
ppl = []
for spath in song_paths:
    
    ppl += [Person(**d) for d in pmap(json.load(open(spath))) ]
ppl
# Out:
# [<Person(name='Hall & Oates' type='artist'),
#  <Person(name='Daryl Hall' type='songwriter'),
#  <Person(name='Janna Allen' type='songwriter'),
#  <Person(name='Daryl Hall' type='producer'),
#  <Person(name='John Oates' type='producer'),
#  <Person(name='The Four Seasons' type='artist'),
#  <Person(name='Van Halen' type='artist'),
#  <Person(name='Eddie Van Halen' type='songwriter'),
#  <Person(name='Michael Anthony' type='songwriter'),
#  <Person(name='Sammy Hagar' type='songwriter'),
#  <Person(name='Alex Van Halen' type='songwriter'),
#  <Person(name='Mick Jones' type='producer'),
#  <Person(name='Donn Landee' type='producer'),
#  <Person(name='Eddie Van Halen' type='producer'),
#  <Person(name='MIchael Anthony' type='producer'),
#  <Person(name='Sammy Hagar' type='producer'),
#  <Person(name='Alex Van Halen' type='producer'),
#  <Person(name='Barry White' type='artist'),
#  <Person(name='Electric Light Orchestra' type='artist'),
#  <Person(name='George McCrae' type='artist'),
#  <Person(name='Gary Lewis & the Playboys' type='artist'),
#  <Person(name='Amy Winehouse' type='artist'),
#  <Person(name='Rod Stewart' type='artist'),
#  <Person(name='The Pipkins' type='artist'),
#  <Person(name='Ed Sheeran' type='artist'),
#  <Person(name='Justin Bieber' type='artist'),
#  <Person(name='Ed Sheeran' type='songwriter'),
#  <Person(name='Justin Bieber' type='songwriter'),
#  <Person(name='Max Martin' type='songwriter'),
#  <Person(name='Shellback' type='songwriter'),
#  <Person(name='Fred Gibson' type='songwriter'),
#  <Person(name='Jason Boyd' type='songwriter'),
#  <Person(name='Max Martin' type='producer'),
#  <Person(name='Shellback' type='producer'),
#  <Person(name='Fred' type='producer'),
#  <Person(name='Engelbert Humperdinck' type='artist'),
#  <Person(name='T-Pain' type='artist'),
#  <Person(name='Mike Jones' type='artist'),
#  <Person(name='Drake' type='artist'),
#  <Person(name='Aubrey Graham' type='songwriter'),
#  <Person(name='Ozan Yildirim' type='songwriter'),
#  <Person(name='Otis Clay' type='artist'),
#  <Person(name='Survivor' type='artist'),
#  <Person(name='Bruce Springsteen' type='artist'),
#  <Person(name='Bruce Springsteen' type='producer'),
#  <Person(name='Chuck Plotkin' type='producer'),
#  <Person(name='Destiny's Child' type='artist'),
#  <Person(name='Wyclef Jean' type='artist'),
#  <Person(name='Vincent Herbert' type='songwriter'),
#  <Person(name='Rob Fusari' type='songwriter'),
#  <Person(name='Mary Brown' type='songwriter'),
#  <Person(name='Calvin Gaines' type='songwriter'),
#  <Person(name='Barry White (Part 2)' type='songwriter'),
#  <Person(name='Vincent Herbert' type='producer'),
#  <Person(name='Rob Fusari' type='producer'),
#  <Person(name='Wyclef Jean' type='producer'),
#  <Person(name='ABC' type='artist'),
#  <Person(name='Martin Fry' type='songwriter'),
#  <Person(name='Mark White' type='songwriter'),
#  <Person(name='Martin Fry' type='producer'),
#  <Person(name='Mark White' type='producer'),
#  <Person(name='Ariana Grande' type='artist'),
#  <Person(name='Nicki Minaj' type='artist'),
#  <Person(name='Max Martin' type='songwriter'),
#  <Person(name='Savan Kotecha' type='songwriter'),
#  <Person(name='Alexander Kronlund' type='songwriter'),
#  <Person(name='Ilya Salmanzadeh' type='songwriter'),
#  <Person(name='Onika Maraj' type='songwriter'),
#  <Person(name='Ariana Grande' type='songwriter'),
#  <Person(name='Max Martin' type='producer'),
#  <Person(name='Ilya' type='producer'),
#  <Person(name='Pitbull' type='artist'),
#  <Person(name='Ne-Yo' type='artist'),
#  <Person(name='Armando C. Pérez' type='songwriter'),
#  <Person(name='Lukasz Gottwald' type='songwriter'),
#  <Person(name='Henry Walter' type='songwriter'),
#  <Person(name='Shaffer Smith' type='songwriter'),
#  <Person(name='Vinay Rao' type='songwriter'),
#  <Person(name='Stephan Taft' type='songwriter'),
#  <Person(name='Michael "Freakin" Everett' type='songwriter'),
#  <Person(name='Dr. Luke' type='producer'),
#  <Person(name='Cirkut' type='producer'),
#  <Person(name='Lifted' type='producer'),
#  <Person(name='Michael "Freakin" Everett (melody)' type='producer'),
#  <Person(name='Karyn White' type='artist'),
#  <Person(name='L.A. Reid' type='songwriter'),
#  <Person(name='Babyface' type='songwriter'),
#  <Person(name='Daryl Simmons' type='songwriter'),
#  <Person(name='L.A. Reid' type='producer'),
#  <Person(name='Babyface' type='producer'),
#  <Person(name='Daryl Simmons' type='producer'),
#  <Person(name='Stacey Q' type='artist'),
#  <Person(name='John Mitchell' type='songwriter'),
#  <Person(name='Tim Greene' type='songwriter'),
#  <Person(name='Sue Gatlin' type='songwriter'),
#  <Person(name='Carpenters' type='artist'),
#  <Person(name='James Brown' type='artist'),
#  <Person(name='James Brown' type='songwriter'),
#  <Person(name='Alfred Ellis' type='songwriter'),
#  <Person(name='Electric Light Orchestra' type='artist'),
#  <Person(name='Fleetwood Mac' type='artist'),
#  <Person(name='Fleetwood Mac' type='producer'),
#  <Person(name='Richard Dashut' type='producer'),
#  <Person(name='Ken Caillat' type='producer'),
#  <Person(name='Hanson' type='artist'),
#  <Person(name='Isaac Hanson' type='songwriter'),
#  <Person(name='Taylor Hanson' type='songwriter'),
#  <Person(name='Zac Hanson' type='songwriter'),
#  <Person(name='Dust Brothers' type='producer'),
#  <Person(name='Stephen Lironi' type='producer'),
#  <Person(name='Jim Stafford' type='artist'),
#  <Person(name='Michael Jackson' type='artist'),
#  <Person(name='INXS' type='artist'),
#  <Person(name='Andrew Farriss' type='songwriter'),
#  <Person(name='Michael Hutchence' type='songwriter'),
#  <Person(name='Fats Domino' type='artist'),
#  <Person(name='Sam Cooke' type='artist'),
#  <Person(name='Huey Lewis and the News' type='artist'),
#  <Person(name='Macklemore & Ryan Lewis' type='artist'),
#  <Person(name='Ray Dalton' type='artist'),
#  <Person(name='Ben Haggerty' type='songwriter'),
#  <Person(name='Ryan Lewis' type='songwriter'),
#  <Person(name='Ray Dalton' type='songwriter'),
#  <Person(name='Jean Knight' type='artist'),
#  <Person(name='Iggy Pop' type='artist'),
#  <Person(name='Elvis Presley' type='artist'),
#  <Person(name='Winfield Scott' type='songwriter'),
#  <Person(name='Otis Blackwell' type='songwriter'),
#  <Person(name='Village People' type='artist'),
#  <Person(name='Jacques Morali' type='songwriter'),
#  <Person(name='Henri Belolo' type='songwriter'),
#  <Person(name='Victor Willis' type='songwriter'),
#  <Person(name='Billy Joel' type='artist'),
#  <Person(name='The Rascals' type='artist'),
#  <Person(name='Gladys Knight & the Pips' type='artist'),
#  <Person(name='the McCoys' type='artist'),
#  <Person(name='Wes Farrell' type='songwriter'),
#  <Person(name='Bert Berns' type='songwriter'),
#  <Person(name='Bob Feldman' type='producer'),
#  <Person(name='Jerry Goldstein' type='producer'),
#  <Person(name='Richard Gottehrer' type='producer'),
#  <Person(name='M.I.A.' type='artist'),
#  <Person(name='Maya "M.I.A." Arulpragasam' type='songwriter'),
#  <Person(name='Wesley "Diplo" Pentz' type='songwriter'),
#  <Person(name='Topper Headon' type='songwriter'),
#  <Person(name='Mick Jones' type='songwriter'),
#  <Person(name='Paul Simonon' type='songwriter'),
#  <Person(name='Joe Strummer' type='songwriter'),
#  <Person(name='M.I.A.' type='producer'),
#  <Person(name='Diplo' type='producer'),
#  <Person(name='Commodores' type='artist'),
#  <Person(name='Gary Wright' type='artist'),
#  <Person(name='Tom Waits' type='artist'),
#  <Person(name='Destiny's Child' type='artist'),
#  <Person(name='Beyoncé Knowles' type='songwriter'),
#  <Person(name='Anthony Dent' type='songwriter'),
#  <Person(name='Mathew Knowles' type='songwriter'),
#  <Person(name='Anthony Dent' type='producer'),
#  <Person(name='Beyoncé Knowles' type='producer'),
#  <Person(name='Snoop Dogg' type='artist'),
#  <Person(name='Pharrell' type='artist'),
#  <Person(name='Chad Hugo' type='songwriter'),
#  <Person(name='Calvin Broadus' type='songwriter'),
#  <Person(name='Pharrell Williams' type='songwriter'),
#  <Person(name='Tim Stahl' type='songwriter'),
#  <Person(name='John Guldberg' type='songwriter'),
#  <Person(name='P.M. Dawn' type='artist'),
#  <Person(name='Attrell Cordes' type='songwriter'),
#  <Person(name='George Michael' type='songwriter'),
#  <Person(name='The Dovells' type='artist'),
#  <Person(name='Luther Ingram' type='artist'),
#  <Person(name='Steve Perry' type='artist'),
#  <Person(name='Steve Perry' type='songwriter'),
#  <Person(name='Randy Goodrum' type='songwriter'),
#  <Person(name='Craig Krampf' type='songwriter'),
#  <Person(name='Bill Cuomo' type='songwriter'),
#  <Person(name='Steve Perry' type='producer'),
#  <Person(name='Bruce Botnick' type='producer'),
#  <Person(name='Tony! Toni! Toné!' type='artist'),
#  <Person(name='The Association' type='artist'),
#  <Person(name='Ray Price' type='artist'),
#  <Person(name='America' type='artist'),
#  <Person(name='Dave Loggins' type='artist'),
#  <Person(name='Tara Kemp' type='artist'),
#  <Person(name='Jake Smith' type='songwriter'),
#  <Person(name='Tuhin Roy' type='songwriter'),
#  <Person(name='William Hammond' type='songwriter'),
#  <Person(name='Jake Smith' type='producer'),
#  <Person(name='Tuhin Roy' type='producer'),
#  <Person(name='Stray Cats' type='artist'),
#  <Person(name='Rex Smith' type='artist'),
#  <Person(name='Rick Springfield' type='artist'),
#  <Person(name='Nelly' type='artist'),
#  <Person(name='Cornell Haynes, Jr.' type='songwriter'),
#  <Person(name='James Scheffer' type='songwriter'),
#  <Person(name='Richard Butler, Jr.' type='songwriter'),
#  <Person(name='Frank Romano' type='songwriter'),
#  <Person(name='Jim Jonsin' type='producer'),
#  <Person(name='Rico Love' type='producer'),
#  <Person(name='Eminem' type='artist'),
#  <Person(name='Nate Dogg' type='artist'),
#  <Person(name='Marshall Mathers' type='songwriter'),
#  <Person(name='Nathaniel Hale' type='songwriter'),
#  <Person(name='Luis Resto' type='songwriter'),
#  <Person(name='Steve King' type='songwriter'),
#  <Person(name='Eminem' type='producer'),
#  <Person(name='Luis Resto (add.)' type='producer'),
#  <Person(name='OutKast' type='artist'),
#  <Person(name='the Yardbirds' type='artist'),
#  <Person(name='Heatwave' type='artist'),
#  <Person(name='David Bowie' type='artist'),
#  <Person(name='David Bowie' type='producer'),
#  <Person(name='Harry Maslin' type='producer'),
#  <Person(name='Rihanna' type='artist'),
#  <Person(name='Brian Kennedy' type='songwriter'),
#  <Person(name='Chris Brown' type='songwriter'),
#  <Person(name='Robert Allen' type='songwriter'),
#  <Person(name='Andre Merritt' type='songwriter'),
#  <Person(name='Brian Kennedy' type='producer'),
#  <Person(name='Makeba Riddick' type='producer'),
#  <Person(name='Roy Orbison' type='artist'),
#  <Person(name='Donny Osmond' type='artist'),
#  <Person(name='DJ Snake' type='artist'),
#  <Person(name='Lil Jon' type='artist'),
#  <Person(name='DJ Snake' type='songwriter'),
#  <Person(name='Steve Guess' type='songwriter'),
#  <Person(name='Lil Jon' type='songwriter'),
#  <Person(name='DJ Snake' type='producer'),
#  <Person(name='Lil Jon' type='producer'),
#  <Person(name='Duran Duran' type='artist'),
#  <Person(name='Simon Le Bon' type='songwriter'),
#  <Person(name='John Taylor' type='songwriter'),
#  <Person(name='Nick Rhodes' type='songwriter'),
#  <Person(name='Duran Duran' type='producer'),
#  <Person(name='Nile Rodgers' type='producer'),
#  <Person(name='Blue Magic' type='artist'),
#  <Person(name='J. Cole' type='artist'),
#  <Person(name='Gregory Abbott' type='artist'),
#  <Person(name='Taylor Swift' type='artist'),
#  <Person(name='Taylor Swift' type='songwriter'),
#  <Person(name='Aaron Dessner' type='songwriter'),
#  <Person(name='Madonna' type='artist'),
#  <Person(name='Madonna' type='songwriter'),
#  <Person(name='Stephen Bray' type='songwriter'),
#  <Person(name='Madonna' type='producer'),
#  <Person(name='Stephen Bray' type='producer'),
#  <Person(name='Jackie DeShannon' type='artist'),
#  <Person(name='Hinder' type='artist'),
#  <Person(name='Austin Winkler' type='songwriter'),
#  <Person(name='Cody Hanson' type='songwriter'),
#  <Person(name='Brian Howes' type='songwriter'),
#  <Person(name='Joseph Lombardo' type='songwriter'),
#  <Person(name='Sean Paul' type='artist'),
#  <Person(name='Sean Paul Henriques' type='songwriter'),
#  <Person(name='Adrian "IZES" Marshall' type='songwriter'),
#  <Person(name='Rohan Fuller' type='songwriter'),
#  <Person(name='Steve Lawrence' type='artist'),
#  <Person(name='Ludacris' type='artist'),
#  <Person(name='Bobby Valentino' type='artist'),
#  <Person(name='New Kids on the Block' type='artist'),
#  <Person(name='Allan Sherman' type='artist'),
#  <Person(name='David Seville' type='artist'),
#  <Person(name='The Chipmunks' type='artist'),
#  <Person(name='Elton John' type='artist'),
#  <Person(name='Chris de Burgh' type='artist'),
#  <Person(name='Jay Sean' type='artist'),
#  <Person(name='Lil Wayne' type='artist'),
#  <Person(name='Kamaljit Jhooti' type='songwriter'),
#  <Person(name='Dwayne Carter' type='songwriter'),
#  <Person(name='Jared Cotter' type='songwriter'),
#  <Person(name='J-Remy' type='songwriter'),
#  <Person(name='Bobby Bass' type='songwriter'),
#  <Person(name='Jonathan Perkins' type='songwriter'),
#  <Person(name='J-Remy' type='producer'),
#  <Person(name='Bobby Bass' type='producer'),
#  <Person(name='Jan and Dean' type='artist'),
#  <Person(name='The Doobie Brothers' type='artist'),
#  <Person(name='Culture Club' type='artist'),
#  <Person(name='Boy George' type='songwriter'),
#  <Person(name='Jon Moss' type='songwriter'),
#  <Person(name='Mikey Craig' type='songwriter'),
#  <Person(name='Roy Hay' type='songwriter'),
#  <Person(name='Phil Pickett' type='songwriter'),
#  <Person(name='Cornelius Brothers & Sister Rose' type='artist'),
#  <Person(name='The Supremes' type='artist'),
#  <Person(name='Divine' type='artist'),
#  <Person(name='Bruce Springsteen' type='artist'),
#  <Person(name='Jon Landau' type='producer'),
#  <Person(name='Chuck Plotkin' type='producer'),
#  <Person(name='Bruce Springsteen' type='producer'),
#  <Person(name='Steven Van Zandt' type='producer'),
#  <Person(name='John Denver' type='artist'),
#  <Person(name='Falco' type='artist'),
#  <Person(name='Falco' type='songwriter'),
#  <Person(name='Rob Bolland' type='songwriter'),
#  <Person(name='Ferdi Bolland' type='songwriter'),
#  <Person(name='Ray Fraser' type='songwriter'),
#  <Person(name='Matthew Jacobson' type='songwriter'),
#  <Person(name='Marshall Mathers' type='songwriter'),
#  <Person(name='Luis Resto' type='songwriter'),
#  <Person(name='Ronald Spence, Jr.' type='songwriter'),
#  <Person(name='Illa da Producer' type='producer'),
#  <Person(name='Ronny J' type='producer'),
#  <Person(name='Eminem' type='producer'),
#  <Person(name='Justin Bieber' type='artist'),
#  <Person(name='Big Sean' type='artist'),
#  <Person(name='Andre Lindal' type='songwriter'),
#  <Person(name='Justin Bieber' type='songwriter'),
#  <Person(name='Nasri Atweh' type='songwriter'),
#  <Person(name='Rodney Jerkins' type='songwriter'),
#  <Person(name='Sean Anderson' type='songwriter'),
#  <Person(name='Darkchild' type='producer'),
#  <Person(name='Andre Lindal' type='producer'),
#  <Person(name='Burl Ives' type='artist'),
#  <Person(name='the Coasters' type='artist'),
#  <Person(name='Johnny Horton' type='artist'),
#  <Person(name='Steppenwolf' type='artist'),
#  <Person(name='XXXTentacion' type='artist'),
#  <Person(name='Jahseh Onfroy' type='songwriter'),
#  <Person(name='John Cunningham' type='songwriter'),
#  <Person(name='Imagine Dragons' type='artist'),
#  <Person(name='Dan Reynolds' type='songwriter'),
#  <Person(name='Wayne Sermon' type='songwriter'),
#  <Person(name='Ben McKee' type='songwriter'),
#  <Person(name='Daniel Platzman' type='songwriter'),
#  <Person(name='Alexander Grant' type='songwriter'),
#  <Person(name='Jayson DeZuzio' type='songwriter'),
#  <Person(name='Alex Da Kid' type='producer'),
#  <Person(name='Jayson DeZuzio' type='producer'),
#  <Person(name='Foreigner' type='artist'),
#  <Person(name='Gary Lyons' type='producer'),
#  <Person(name='John Sinclair' type='producer'),
#  <Person(name='Brenda Lee' type='artist'),
#  <Person(name='Bruce Springsteen' type='artist'),
#  <Person(name='Jon Landau' type='producer'),
#  <Person(name='Chuck Plotkin' type='producer'),
#  <Person(name='Bruce Springsteen' type='producer'),
#  <Person(name='Steven Van Zandt' type='producer'),
#  <Person(name='Lil' Kim' type='artist'),
#  <Person(name='Da Brat' type='artist'),
#  <Person(name='Left Eye' type='artist'),
#  <Person(name='Missy "Misdeameanor" Elliott' type='artist'),
#  <Person(name='Angie Martinez' type='artist'),
#  <Person(name='Kimberly Jones' type='songwriter'),
#  <Person(name='Lisa Lopes' type='songwriter'),
#  <Person(name='Shawntae Harris' type='songwriter'),
#  <Person(name='Angela Martinez' type='songwriter'),
#  <Person(name='Melissa Elliott' type='songwriter'),
#  <Person(name='Armando Colon' type='producer'),
#  <Person(name='Rashad "Ringo" Smith' type='producer'),
#  <Person(name='A Taste of Honey' type='artist'),
#  <Person(name='Luther Vandross' type='artist'),
#  <Person(name='Janet Jackson' type='artist'),
#  <Person(name='Bell Biv DeVoe' type='artist'),
#  <Person(name='Ralph Tresvant' type='artist'),
#  <Person(name='Jimmy Jam and Terry Lewis' type='songwriter'),
#  <Person(name='Michael Bivins' type='songwriter'),
#  <Person(name='Ronnie DeVoe' type='songwriter'),
#  <Person(name='Harry Wayne Casey' type='songwriter'),
#  <Person(name='Richard Finch' type='songwriter'),
#  <Person(name='Toto' type='artist'),
#  <Person(name='Jonas Brothers' type='artist'),
#  <Person(name='Nick Jonas' type='songwriter'),
#  <Person(name='Joe Jonas' type='songwriter'),
#  <Person(name='Kevin Jonas' type='songwriter'),
#  <Person(name='Greg Garbowsky' type='songwriter'),
#  <Person(name='Neil Sedaka' type='artist'),
#  <Person(name='Taylor Swift' type='artist'),
#  <Person(name='Taylor Swift' type='songwriter'),
#  <Person(name='Joel Little' type='songwriter'),
#  <Person(name='Joel Little' type='producer'),
#  <Person(name='Taylor Swift' type='producer'),
#  <Person(name='Nicki Minaj' type='artist'),
#  <Person(name='Onika Maraj' type='songwriter'),
#  <Person(name='Jeremy Reid' type='songwriter'),
#  <Person(name='Reid' type='producer'),
#  <Person(name='Minaj' type='producer'),
#  <Person(name='the Five Americans' type='artist'),
#  <Person(name='John Durrill' type='songwriter'),
#  <Person(name='Michael Rabon' type='songwriter'),
#  <Person(name='Norm Ezell' type='songwriter'),
#  <Person(name='Jade' type='artist'),
#  <Person(name='Vassal Benford III' type='songwriter'),
#  <Person(name='Ronald Spearman' type='songwriter'),
#  <Person(name='Vassal Benford III' type='producer'),
#  <Person(name='Ronald Spearman' type='producer'),
#  <Person(name='Michael Jackson' type='artist'),
#  <Person(name='Michael Jackson' type='songwriter'),
#  <Person(name='Darkchild' type='songwriter'),
#  <Person(name='Michael Jackson' type='producer'),
#  <Person(name='Darkchild' type='producer'),
#  <Person(name='Henry Gross' type='artist'),
#  <Person(name='Eddie Murphy' type='artist'),
#  <Person(name='Dexy's Midnight Runners and the Emerald Express' type='artist'),
#  <Person(name='Kevin Rowland' type='songwriter'),
#  <Person(name='Jim Paterson' type='songwriter'),
#  <Person(name='Billy Adams' type='songwriter'),
#  <Person(name='Clive Langer' type='producer'),
#  <Person(name='Alan Winstanley' type='producer'),
#  <Person(name='Celine Dion' type='artist'),
#  <Person(name='Robert White Johnson' type='songwriter'),
#  <Person(name='Taylor Rhodes' type='songwriter'),
#  <Person(name='Van McCoy' type='artist'),
#  <Person(name='Ron Holden' type='artist'),
#  <Person(name='Kanye West' type='artist'),
#  <Person(name='Jamie Foxx' type='artist'),
#  <Person(name='Kanye West' type='songwriter'),
#  <Person(name='Ray Charles' type='songwriter'),
#  <Person(name='Renald Richard' type='songwriter'),
#  <Person(name='Kanye West' type='producer'),
#  <Person(name='Jon Brion' type='producer'),
#  <Person(name='Usher' type='artist'),
#  <Person(name='Usher' type='songwriter'),
#  <Person(name='Jermaine Dupri' type='songwriter'),
#  <Person(name='Manuel Seal' type='songwriter'),
#  <Person(name='Jermaine Dupri' type='producer'),
#  <Person(name='Manuel Seal' type='producer'),
#  <Person(name='Sting' type='artist'),
#  <Person(name='Sting' type='producer'),
#  <Person(name='Peter Smith' type='producer'),
#  <Person(name='French Montana' type='artist'),
#  <Person(name='Swae Lee' type='artist'),
#  <Person(name='Karim Kharbouch' type='songwriter'),
#  <Person(name='Khalif Brown' type='songwriter'),
#  <Person(name='Christopher Washington' type='songwriter'),
#  <Person(name='Jake Aujla' type='songwriter'),
#  <Person(name='McCulloch Sutphin' type='songwriter'),
#  <Person(name='Jaegen' type='producer'),
#  <Person(name='1Mind' type='producer'),
#  <Person(name='C.P Dubb' type='producer'),
#  <Person(name='Mike WiLL Made-It' type='producer'),
#  <Person(name='Chicago' type='artist'),
#  <Person(name='Pitbull' type='artist'),
#  <Person(name='Armando Peréz' type='songwriter'),
#  <Person(name='Edward Bello' type='songwriter'),
#  <Person(name='Daniel Seraphine' type='songwriter'),
#  <Person(name='David Wolinski' type='songwriter'),
#  <Person(name='Nicola Fasano' type='songwriter'),
#  <Person(name='Paul Gonella' type='songwriter'),
#  <Person(name='Stefano Bosco' type='songwriter'),
#  <Person(name='Crash Test Dummies' type='artist'),
#  <Person(name='Jerry Harrison' type='producer'),
#  <Person(name='Crash Test Dummies' type='producer'),
#  <Person(name='Jody Watley' type='artist'),
#  <Person(name='Eric B. & Rakim' type='artist'),
#  <Person(name='The Stampeders' type='artist'),
#  <Person(name='Wild Cherry' type='artist'),
#  <Person(name='Natasha Bedingfield' type='artist'),
#  <Person(name='Natasha Bedingfield' type='songwriter'),
#  <Person(name='Danielle Brisebois' type='songwriter'),
#  <Person(name='Wayne Rodrigues' type='songwriter'),
#  <Person(name='Wayne Rodrigues' type='producer'),
#  <Person(name='Danielle Brisebois' type='producer'),
#  <Person(name='Bobby Vinton' type='artist'),
#  <Person(name='Johnny Tillotson' type='artist'),
#  <Person(name='Anne Murray' type='artist'),
#  <Person(name='Al Stewart' type='artist'),
#  <Person(name='Johnny Mathis' type='artist'),
#  <Person(name='Brick' type='artist'),
#  <Person(name='Johnny Lee' type='artist'),
#  <Person(name='Jason Mraz' type='artist'),
#  <Person(name='The Police' type='artist'),
#  <Person(name='Nigel Gray' type='producer'),
#  <Person(name='Stewart Copeland' type='producer'),
#  <Person(name='Sting' type='producer'),
#  <Person(name='Andy Summers' type='producer'),
#  <Person(name='Gary Puckett & The Union Gap' type='artist'),
#  <Person(name='J Balvin' type='artist'),
#  <Person(name='Willy William' type='artist'),
#  <Person(name='José Osorio' type='songwriter'),
#  <Person(name='Willy William' type='songwriter'),
#  <Person(name='Adam Assad' type='songwriter'),
#  <Person(name='Andrés David Restrepo' type='songwriter'),
#  <Person(name='Mohombi Nzasi Moupondo' type='songwriter'),
#  <Person(name='The Dells' type='artist'),
#  <Person(name='Wade Flemons' type='songwriter'),
#  <Person(name='Robert Eugene Miller' type='songwriter'),
#  <Person(name='Barrett Strong' type='songwriter'),
#  <Person(name='Heart' type='artist'),
#  <Person(name='Gloria Loring' type='artist'),
#  <Person(name='Carl Anderson' type='artist'),
#  <Person(name='Peter Cetera' type='artist'),
#  <Person(name='Amy Grant' type='artist'),
#  <Person(name='Bobby Caldwell' type='songwriter'),
#  <Person(name='Paul Gordon' type='songwriter'),
#  <Person(name='Gershon Kingsley' type='artist'),
#  <Person(name='Clean Bandit' type='artist'),
#  <Person(name='Jess Glynne' type='artist'),
#  <Person(name='Jack Patterson' type='songwriter'),
#  <Person(name='James Napier' type='songwriter'),
#  <Person(name='Nicole Marshall' type='songwriter'),
#  <Person(name='Grace Chatto' type='songwriter'),
#  <Person(name='Grace Chatto' type='producer'),
#  <Person(name='Jack Patterson' type='producer'),
#  <Person(name='Pitbull' type='artist'),
#  <Person(name='T-Pain' type='artist'),
#  <Person(name='Armando C. Pérez' type='songwriter'),
#  <Person(name='Faheem Najm' type='songwriter'),
#  <Person(name='Sandy Wilhelm' type='songwriter'),
#  <Person(name='Lenny Kravitz' type='artist'),
#  <Person(name='Edwin Hawkins Singers' type='artist'),
#  <Person(name='Selena Gomez' type='artist'),
#  <Person(name='Selena Gomez' type='songwriter'),
#  <Person(name='Antonina Armato' type='songwriter'),
#  <Person(name='David Jost' type='songwriter'),
#  <Person(name='Tim James' type='songwriter'),
#  <Person(name='Rock Mafia' type='producer'),
#  <Person(name='Babyface' type='artist'),
#  <Person(name='Aretha Franklin' type='artist'),
#  <Person(name='Gerry Goffin' type='songwriter'),
#  <Person(name='Carole King' type='songwriter'),
#  <Person(name='Jerry Wexler' type='songwriter'),
#  <Person(name='Raspberries' type='artist'),
#  <Person(name='Gloria Estefan' type='artist'),
#  <Person(name='Miami Sound Machine' type='artist'),
#  <Person(name='Ben E. King' type='artist'),
#  <Person(name='Jerry Leiber' type='songwriter'),
#  <Person(name='Phil Spector' type='songwriter'),
#  <Person(name='Gladys Knight & the Pips' type='artist'),
#  <Person(name='Gloria Jones' type='songwriter'),
#  <Person(name='Clay McMurray' type='songwriter'),
#  <Person(name='Pam Sawyer' type='songwriter'),
#  <Person(name='The Safaris' type='artist'),
#  <Person(name='Gary Glitter' type='artist'),
#  <Person(name='Gary Glitter' type='songwriter'),
#  <Person(name='Mike Leander' type='songwriter'),
#  <Person(name='Desiigner' type='artist'),
#  <Person(name='Sidney Selby III' type='songwriter'),
#  <Person(name='Nico & Vinz' type='artist'),
#  <Person(name='[A]' type='artist'),
#  <Person(name='William Wiik Larsen' type='songwriter'),
#  <Person(name='Nico Sereba' type='songwriter'),
#  <Person(name='Vincent Dery' type='songwriter'),
#  <Person(name='Abdoulie Jallow' type='songwriter'),
#  <Person(name='Train' type='artist'),
#  <Person(name='Patrick Monahan' type='songwriter'),
#  <Person(name='Espen Lind' type='songwriter'),
#  <Person(name='Amund Bjørklund' type='songwriter'),
#  <Person(name='Espionage' type='producer'),
#  <Person(name='Martin Terefe' type='producer'),
#  <Person(name='Gregg Wattenberg' type='producer'),
#  <Person(name='Christopher Cross' type='artist'),
#  <Person(name='the Crickets' type='artist'),
#  <Person(name='The Everly Brothers' type='artist'),
#  <Person(name='George Michael' type='artist'),
#  <Person(name='Real McCoy' type='artist'),
#  <Person(name='Juergen Wind (J.Wind)' type='songwriter'),
#  <Person(name='Quickmix' type='songwriter'),
#  <Person(name='Olaf Jeglitza' type='songwriter'),
#  <Person(name='Juergen Wind (J.Wind)' type='producer'),
#  <Person(name='Frank Hassas' type='producer'),
#  <Person(name='The Turtles' type='artist'),
#  <Person(name='Whitney Houston' type='artist'),
#  <Person(name='Paul McCartney' type='artist'),
#  <Person(name='George Michael' type='artist'),
#  <Person(name='Fleetwood Mac' type='artist'),
#  <Person(name='Fleetwood Mac' type='producer'),
#  <Person(name='Richard Dashut' type='producer'),
#  <Person(name='Ken Caillat' type='producer'),
#  <Person(name='Groove Theory' type='artist'),
#  <Person(name='Rome' type='artist'),
#  <Person(name='Jerome Woods' type='songwriter'),
#  <Person(name='Gerald Baillergeau' type='songwriter'),
#  <Person(name='Gerald Baillergeau' type='producer'),
#  <Person(name='Victor Merritt' type='producer'),
#  <Person(name='OneRepublic' type='artist'),
#  <Person(name='Ryan Tedder' type='producer'),
#  <Person(name='Noel Zancanella' type='producer'),
#  <Person(name='Dinah Washington' type='artist'),
#  <Person(name='Rod Stewart' type='artist'),
#  <Person(name='Stonewall Jackson' type='artist'),
#  <Person(name='Suzanne Vega' type='artist'),
#  <Person(name='Steve Addabbo' type='producer'),
#  <Person(name='Lenny Kaye' type='producer'),
#  <Person(name='Johnnie Taylor' type='artist'),
#  <Person(name='Homer Banks' type='songwriter'),
#  <Person(name='Bettye Crutcher' type='songwriter'),
#  <Person(name='Don Davis' type='songwriter'),
#  <Person(name='Raymond Jackson' type='songwriter'),
#  <Person(name='Carrie Underwood' type='artist'),
#  <Person(name='Josh Kear' type='songwriter'),
#  <Person(name='Chris Tompkins' type='songwriter'),
#  <Person(name='Petula Clark' type='artist'),
#  <Person(name='T-Pain' type='artist'),
#  <Person(name='Bobby Helms' type='artist'),
#  <Person(name='Joe Beal' type='songwriter'),
#  <Person(name='Jim Boothe' type='songwriter'),
#  <Person(name='Frankie Valli' type='artist'),
#  <Person(name='Buffalo Springfield' type='artist'),
#  <Person(name='Charles Greene' type='producer'),
#  <Person(name='Brian Stone' type='producer'),
#  <Person(name='Guns N' Roses' type='artist'),
#  <Person(name='Finger Eleven' type='artist'),
#  <Person(name='Scott Anderson' type='songwriter'),
#  <Person(name='Sean Anderson' type='songwriter'),
#  <Person(name='Rich Beddoe' type='songwriter'),
#  <Person(name='James Black' type='songwriter'),
#  <Person(name='Rick Jackett' type='songwriter'),
#  <Person(name='Paula Abdul' type='artist'),
#  <Person(name='Diana Ross' type='artist'),
#  <Person(name='Carole Bayer Sager' type='songwriter'),
#  <Person(name='Michael Masser' type='songwriter'),
#  <Person(name='Lionel Richie' type='artist'),
#  <Person(name='Donna Summer' type='artist'),
#  <Person(name='Donna Summer' type='songwriter'),
#  <Person(name='Michael Omartian' type='songwriter'),
#  <Person(name='Evelyn "Champagne" King' type='artist'),
#  <Person(name='Paul Anka' type='artist'),
#  <Person(name='Little River Band' type='artist'),
#  <Person(name='Linda Ronstadt' type='artist'),
#  <Person(name='Aaron Neville' type='artist'),
#  <Person(name='Barry Mann' type='songwriter'),
#  <Person(name='Cynthia Weil' type='songwriter'),
#  <Person(name='Tom Snow' type='songwriter'),
#  <Person(name='Peter Asher' type='producer'),
#  <Person(name='Steve Tyrell' type='producer'),
#  <Person(name='Kool & the Gang' type='artist'),
#  <Person(name='Mariah Carey' type='artist'),
#  <Person(name='Mariah Carey' type='songwriter'),
#  <Person(name='Dave Hall' type='songwriter'),
#  <Person(name='Adrian Belew' type='songwriter'),
#  <Person(name='Chris Frantz' type='songwriter'),
#  <Person(name='Steven Stanley' type='songwriter'),
#  <Person(name='Tina Weymouth' type='songwriter'),
#  <Person(name='Mariah Carey' type='producer'),
#  <Person(name='Dave Hall' type='producer'),
#  <Person(name='Puff Daddy (remix only)' type='producer'),
#  <Person(name='Jackson 5' type='artist'),
#  <Person(name='the Beatles' type='artist'),
#  <Person(name='Bananarama' type='artist'),
#  <Person(name='Sara Dallin' type='songwriter'),
#  <Person(name='Siobhan Fahey' type='songwriter'),
#  <Person(name='Steve Jolley' type='songwriter'),
#  <Person(name='Tony Swain' type='songwriter'),
#  <Person(name='Keren Woodward' type='songwriter'),
#  <Person(name='Doris Day' type='artist'),
#  <Person(name='Edward Heyman' type='songwriter'),
#  <Person(name='Victor Young' type='songwriter'),
#  <Person(name='Charlie Ryan' type='artist'),
#  <Person(name='Leo Sayer' type='artist'),
#  <Person(name='Kesha' type='artist'),
#  <Person(name='Kesha Sebert' type='songwriter'),
#  <Person(name='Lukasz Gottwald' type='songwriter'),
#  <Person(name='Claude Kelly' type='songwriter'),
#  <Person(name='Pink' type='artist'),
#  <Person(name='Pink' type='songwriter'),
#  <Person(name='Max Martin' type='songwriter'),
#  <Person(name='Shellback' type='songwriter'),
#  <Person(name='Candyman' type='artist'),
#  <Person(name='Eddie Floyd' type='artist'),
#  <Person(name='Barry Manilow' type='artist'),
#  <Person(name='Men at Work' type='artist'),
#  <Person(name='Poison' type='artist'),
#  <Person(name='Bret Michaels' type='songwriter'),
#  <Person(name='Rikki Rockett' type='songwriter'),
#  <Person(name='Bobby Dall' type='songwriter'),
#  <Person(name='C.C. DeVille' type='songwriter'),
#  <Person(name='Barbra Streisand' type='artist'),
#  <Person(name='Gary Klein' type='producer'),
#  <Person(name='Charlie Calello' type='producer'),
#  <Person(name='Lonnie Donegan' type='artist'),
#  <Person(name='Lady Gaga' type='artist'),
#  <Person(name='Lady Gaga' type='producer'),
#  <Person(name='Robert John "Mutt" Lange' type='producer'),
#  <Person(name='Bobby Rydell' type='artist'),
#  <Person(name='Phil Collins' type='artist'),
#  <Person(name='Gilbert Bécaud' type='artist'),
#  <Person(name='No Mercy' type='artist'),
#  <Person(name='Peter Bischof' type='songwriter'),
#  <Person(name='Franz Reuther' type='songwriter'),
#  <Person(name='Carpenters' type='artist'),
#  <Person(name='Gary Geld' type='songwriter'),
#  <Person(name='Peter Udell' type='songwriter'),
#  <Person(name='Earth, Wind & Fire' type='artist'),
#  <Person(name='Maurice White' type='songwriter'),
#  <Person(name='Wayne Vaughn' type='songwriter'),
#  <Person(name='Brewer & Shipley' type='artist'),
#  <Person(name='Plain White T's' type='artist'),
#  <Person(name='Ariel Rechtshaid' type='producer'),
#  <Person(name='Sean O'Keefe' type='producer'),
#  <Person(name='U2' type='artist'),
#  <Person(name='Creed' type='artist'),
#  <Person(name='Scott Stapp' type='songwriter'),
#  <Person(name='Mark Tremonti' type='songwriter'),
#  <Person(name='Ron Saint Germain' type='producer'),
#  <Person(name='John Kurzweg' type='producer'),
#  <Person(name='Kiss' type='artist'),
#  <Person(name='Metro Station' type='artist'),
#  <Person(name='Trace Cyrus' type='songwriter'),
#  <Person(name='Mason Musso' type='songwriter'),
#  <Person(name='Blake Healy' type='songwriter'),
#  <Person(name='Anthony Improgo' type='songwriter'),
#  <Person(name='Mariah Carey' type='artist'),
#  <Person(name='Jay-Z' type='artist'),
#  <Person(name='Mariah Carey' type='songwriter'),
#  <Person(name='Shawn Carter' type='songwriter'),
#  <Person(name='Shirley Elliston' type='songwriter'),
#  <Person(name='Lincoln Chase' type='songwriter'),
#  <Person(name='Narada Michael Walden' type='songwriter'),
#  <Person(name='Jeffrey Cohen' type='songwriter'),
#  <Person(name='Mariah Carey' type='producer'),
#  <Person(name='DJ Clue' type='producer'),
#  <Person(name='Ken “Duro” Ifill' type='producer'),
#  <Person(name='Another Bad Creation' type='artist'),
#  <Person(name='Los del Río' type='artist'),
#  <Person(name='Rafael Ruiz Perdigones' type='songwriter'),
#  <Person(name='Antonio Romero Monge' type='songwriter'),
#  <Person(name='SWK' type='songwriter'),
#  <Person(name='Jagged Edge' type='artist'),
#  <Person(name='Samantha Fox' type='artist'),
#  <Person(name='the Kinks' type='artist'),
#  <Person(name='Styx' type='artist'),
#  <Person(name='Gerry and the Pacemakers' type='artist'),
#  <Person(name='Frankie Lymon' type='artist'),
#  <Person(name='The Teenagers' type='artist'),
#  <Person(name='The Winstons' type='artist'),
#  <Person(name='Fabian Forte' type='artist'),
#  <Person(name='Gloria Estefan' type='artist'),
#  <Person(name='Emilio Estefan, Jr.' type='producer'),
#  <Person(name='Jorge Casas' type='producer'),
#  <Person(name='Clay Ostwald' type='producer'),
#  <Person(name='Lana Del Rey' type='artist'),
#  <Person(name='Lana Del Rey' type='songwriter'),
#  <Person(name='Rick Nowels' type='songwriter'),
#  <Person(name='Emile Haynie' type='producer'),
#  <Person(name='Rick Nowels (album version)' type='producer'),
#  <Person(name='Rick Nowels' type='producer'),
#  <Person(name='Devrim Karaoglu (radio mix)' type='producer'),
#  <Person(name='Foreigner' type='artist'),
#  <Person(name='Pharrell Williams' type='artist'),
#  <Person(name='Jay-Z' type='artist'),
#  <Person(name='Pharrell Williams' type='songwriter'),
#  <Person(name='Chad Hugo' type='songwriter'),
#  <Person(name='Shawn Carter' type='songwriter'),
#  <Person(name='Kim Carnes' type='artist'),
#  <Person(name='Donna Weiss' type='songwriter'),
#  <Person(name='Jackie DeShannon' type='songwriter'),
#  <Person(name='Fetty Wap' type='artist'),
#  <Person(name='Willie Maxwell' type='songwriter'),
#  <Person(name='Remy Boyz' type='songwriter'),
#  <Person(name='Brian "Peoples" Garcia' type='producer'),
#  <Person(name='Micah Street' type='producer'),
#  <Person(name='Billy Ocean' type='artist'),
#  <Person(name='Dru Hill' type='artist'),
#  <Person(name='Wilson Phillips' type='artist'),
#  <Person(name='Neil Diamond' type='artist'),
#  <Person(name='Madonna' type='artist'),
#  <Person(name='Brian Elliot' type='songwriter'),
#  <Person(name='Madonna' type='songwriter'),
#  <Person(name='Madonna' type='producer'),
#  <Person(name='Stephen Bray' type='producer'),
#  <Person(name='Usher' type='artist'),
#  <Person(name='will.i.am' type='artist'),
#  <Person(name='William Adams' type='songwriter'),
#  <Person(name='Tommy Roe' type='artist'),
#  <Person(name='The Everly Brothers' type='artist'),
#  <Person(name='David Dante' type='artist'),
#  <Person(name='Anita Bryant' type='artist'),
#  <Person(name='Paul Petersen' type='artist'),
#  <Person(name='War' type='artist'),
#  <Person(name='War' type='songwriter'),
#  <Person(name='Jerry Goldstein' type='songwriter'),
#  <Person(name='Jerry Goldstein' type='producer'),
#  <Person(name='Lonnie Jordan' type='producer'),
#  <Person(name='Howard E. Scott' type='producer'),
#  <Person(name='Little Anthony & The Imperials' type='artist'),
#  <Person(name='Taylor Swift' type='artist'),
#  <Person(name='Taylor Swift' type='songwriter'),
#  <Person(name='Liz Rose' type='songwriter'),
#  <Person(name='Nathan Chapman' type='producer'),
#  <Person(name='Taylor Swift' type='producer'),
#  <Person(name='The Miracles' type='artist'),
#  <Person(name='Elvis Presley' type='artist'),
#  <Person(name='Stephen H. Sholes' type='producer'),
#  <Person(name='Elvis Presley' type='producer'),
#  <Person(name='Far East Movement' type='artist'),
#  <Person(name='Ryan Tedder' type='artist'),
#  <Person(name='Jae Choung' type='songwriter'),
#  <Person(name='James Roh' type='songwriter'),
#  <Person(name='Kevin Nishimura' type='songwriter'),
#  <Person(name='Virman Coquia' type='songwriter'),
#  <Person(name='Jonathan Yip' type='songwriter'),
#  <Person(name='Jeremy Reeves' type='songwriter'),
#  <Person(name='Ray Romulus' type='songwriter'),
#  <Person(name='Bruno Mars' type='songwriter'),
#  <Person(name='Philip Lawrence' type='songwriter'),
#  <Person(name='The Stereotypes' type='producer'),
#  <Person(name='The Smeezingtons' type='producer'),
#  <Person(name='The Beach Boys' type='artist'),
#  <Person(name='Lil Wayne' type='artist'),
#  <Person(name='Jimmy Jones' type='artist'),
#  <Person(name='the Beach Boys' type='artist'),
#  <Person(name='Brian Wilson' type='songwriter'),
#  <Person(name='Mike Love' type='songwriter'),
#  <Person(name='Andy Grammer' type='artist'),
#  <Person(name='Andy Grammer' type='songwriter'),
#  <Person(name='Nolan Sipe' type='songwriter'),
#  <Person(name='Sipe' type='producer'),
#  <Person(name='Brian West' type='producer'),
#  <Person(name='Steve Greenberg' type='producer'),
#  <Person(name='98°' type='artist'),
#  <Person(name='Stevie Nicks' type='artist'),
#  <Person(name='Tom Petty and the Heartbreakers' type='artist'),
#  <Person(name='Tom Petty' type='songwriter'),
#  <Person(name='Mike Campbell' type='songwriter'),
#  <Person(name='Jimmy Iovine' type='producer'),
#  <Person(name='Tom Petty' type='producer'),
#  <Person(name='Missy "Misdemeanor" Elliott' type='artist'),
#  <Person(name='Lil' Mo' type='artist'),
#  <Person(name='Nas' type='artist'),
#  <Person(name='Eve' type='artist'),
#  <Person(name='Q-Tip' type='artist'),
#  <Person(name='Melissa Elliott' type='songwriter'),
#  <Person(name='Timothy Mosley' type='songwriter'),
#  <Person(name='Nasir Jones' type='songwriter'),
#  <Person(name='Eve Jeffers' type='songwriter'),
#  <Person(name='Kamaal Fareed' type='songwriter'),
#  <Person(name='Lil Nas X' type='artist'),
#  <Person(name='Montero Hill' type='songwriter'),
#  <Person(name='Denzel Baptiste' type='songwriter'),
#  <Person(name='David Biral' type='songwriter'),
#  <Person(name='Oladipo Omishore' type='songwriter'),
#  <Person(name='Kurt Cobain' type='songwriter'),
#  <Person(name='Take a Daytrip' type='producer'),
#  <Person(name='Dot da Genius (co.)' type='producer'),
#  <Person(name='Fontella Bass' type='artist'),
#  <Person(name='Raynard Miner' type='songwriter'),
#  <Person(name='Carl Smith' type='songwriter'),
#  <Person(name='Fontella Bass (disputed)' type='songwriter'),
#  <Person(name='Ariana Grande' type='artist'),
#  <Person(name='Mac Miller' type='artist'),
#  <Person(name='Harmony Samuels' type='songwriter'),
#  <Person(name='Amber Streeter' type='songwriter'),
#  <Person(name='Al Sherrod Lambert' type='songwriter'),
#  <Person(name='Jordin Sparks' type='songwriter'),
#  <Person(name='Malcolm McCormick' type='songwriter'),
#  <Person(name='Brenda Russell' type='songwriter'),
#  <Person(name='Harmony Samuels' type='producer'),
#  <Person(name='Hurricane Smith' type='artist'),
#  <Person(name='Thomas Wayne and the DeLons' type='artist'),
#  <Person(name='Ernest Ashworth' type='artist'),
#  <Person(name='Brenda Lee' type='artist'),
#  <Person(name='The Guess Who' type='artist'),
#  <Person(name='the All-American Rejects' type='artist'),
#  <Person(name='Nick Wheeler' type='songwriter'),
#  <Person(name='Tyson Ritter' type='songwriter'),
#  <Person(name='The Left Banke' type='artist'),
#  <Person(name='Michael Brown' type='songwriter'),
#  <Person(name='Bob Calilli' type='songwriter'),
#  <Person(name='Tony Sansone' type='songwriter'),
#  <Person(name='Stan Getz' type='artist'),
#  <Person(name='João Gilberto' type='artist'),
#  <Person(name='the Beatles' type='artist'),
#  <Person(name='Billy Idol' type='artist'),
#  <Person(name='Billy Idol' type='songwriter'),
#  <Person(name='Steve Stevens' type='songwriter'),
#  <Person(name='Lukas Graham' type='artist'),
#  <Person(name='Lukas Forchammer' type='songwriter'),
#  <Person(name='Stefan Forrest' type='songwriter'),
#  <Person(name='Morten Ristorp' type='songwriter'),
#  <Person(name='Morten Pilegaard' type='songwriter'),
#  <Person(name='Future Animals' type='producer'),
#  <Person(name='Pilo' type='producer'),
#  <Person(name='Beyoncé' type='artist'),
#  <Person(name='Slim Thug' type='artist'),
#  <Person(name='Beyoncé Knowles' type='songwriter'),
#  <Person(name='Kasseem Dean' type='songwriter'),
#  <Person(name='Bernard Freeman' type='songwriter'),
#  <Person(name='Sean Garrett' type='songwriter'),
#  <Person(name='Angela Beyincé' type='songwriter'),
#  <Person(name='Stayve Thomas' type='songwriter'),
#  <Person(name='Swizz Beatz' type='producer'),
#  <Person(name='Halsey' type='artist'),
#  <Person(name='Ashley Frangipane' type='songwriter'),
#  <Person(name='Eric Frederic' type='songwriter'),
#  <Person(name='Justin Tranter' type='songwriter'),
#  <Person(name='Rogét Chahayed' type='songwriter'),
#  <Person(name='Ricky Reed' type='producer'),
#  <Person(name='Rogét Chahayed' type='producer'),
#  <Person(name='K-Ci & JoJo' type='artist'),
#  <Person(name='Joel Hailey' type='songwriter'),
#  <Person(name='Rory Bennett' type='songwriter'),
#  <Person(name='Glass Tiger' type='artist'),
#  <Person(name='the Rolling Stones' type='artist'),
#  <Person(name='Donna Summer' type='artist'),
#  <Person(name='Giorgio Moroder' type='producer'),
#  <Person(name='Pete Bellotte' type='producer'),
#  <Person(name='OutKast' type='artist'),
#  <Person(name='André Benjamin' type='songwriter'),
#  <Person(name='Antwan Patton' type='songwriter'),
#  <Person(name='David Sheats' type='songwriter'),
#  <Person(name='Richard Wagner' type='songwriter'),
#  <Person(name='Stan Watts' type='songwriter'),
#  <Person(name='Shuggie Otis' type='songwriter'),
#  <Person(name='Eminem' type='artist'),
#  <Person(name='Rihanna' type='artist'),
#  <Person(name='Marshall Mathers' type='songwriter'),
#  <Person(name='Bleta Rexha' type='songwriter'),
#  <Person(name='Robyn Fenty' type='songwriter'),
#  <Person(name='Aaron Kleinstub' type='songwriter'),
#  <Person(name='Jon Bellion' type='songwriter'),
#  <Person(name='Bryan Fryzel' type='songwriter'),
#  <Person(name='Maki Athanasiou' type='songwriter'),
#  <Person(name='Frequency' type='producer'),
#  <Person(name='Aalias (co.)' type='producer'),
#  <Person(name='Bryan Adams' type='artist'),
#  <Person(name='Vanessa Williams' type='artist'),
#  <Person(name='Phil Galdston' type='songwriter'),
#  <Person(name='Wendy Waldman' type='songwriter'),
#  <Person(name='Jon Lind' type='songwriter'),
#  <Person(name='Billy J. Kramer with the Dakotas' type='artist'),
#  <Person(name='Smokey Robinson & the Miracles' type='artist'),
#  <Person(name='Demi Lovato' type='artist'),
#  <Person(name='Mitch Allan' type='songwriter'),
#  <Person(name='Jason Evigan' type='songwriter'),
#  <Person(name='Sean Douglas' type='songwriter'),
#  <Person(name='Nikki Williams' type='songwriter'),
#  <Person(name='Aaron Philips' type='songwriter'),
#  <Person(name='Demi Lovato' type='songwriter'),
#  <Person(name='Beyoncé' type='artist'),
#  <Person(name='Shakira' type='artist'),
#  <Person(name='Mikkel S. Eriksen' type='songwriter'),
#  <Person(name='Tor Erik Hermansen' type='songwriter'),
#  <Person(name='Amanda Ghost' type='songwriter'),
#  <Person(name='Ian Dench' type='songwriter'),
#  <Person(name='Beyoncé Knowles' type='songwriter'),
#  <Person(name='Stargate' type='producer'),
#  <Person(name='Beyoncé Knowles' type='producer'),
#  <Person(name='the Rooftop Singers' type='artist'),
#  <Person(name='Frankie Valli' type='artist'),
#  <Person(name='Bob Crewe' type='songwriter'),
#  <Person(name='Bob Gaudio' type='songwriter'),
#  <Person(name='Ollie & Jerry' type='artist'),
#  <Person(name='Ernie Maresca' type='artist'),
#  <Person(name='Vangelis' type='artist'),
#  <Person(name='Luis Fonsi' type='artist'),
#  <Person(name='Daddy Yankee' type='artist'),
#  <Person(name='Luis Rodríguez' type='songwriter'),
#  <Person(name='Erika Ender' type='songwriter'),
#  <Person(name='Ramón Ayala' type='songwriter'),
#  <Person(name='Mauricio Rengifo' type='producer'),
#  <Person(name='Andrés Torres' type='producer'),
#  <Person(name='Bread' type='artist'),
#  <Person(name='Marvin Gaye' type='artist'),
#  <Person(name='Skeeter Davis' type='artist'),
#  <Person(name='Arthur Kent' type='songwriter'),
#  <Person(name='Sylvia Dee' type='songwriter'),
#  <Person(name='Nicki Minaj' type='artist'),
#  <Person(name='Onika Maraj' type='songwriter'),
#  <Person(name='Jamal Jones' type='songwriter'),
#  <Person(name='Jonathan Solone-Myvett' type='songwriter'),
#  <Person(name='Ernest Clark' type='songwriter'),
#  <Person(name='Marcos Palacios' type='songwriter'),
#  <Person(name='Ralph Thane' type='songwriter'),
#  <Person(name='Anthony Ray' type='songwriter'),
#  <Person(name='Polow da Don' type='producer'),
#  <Person(name='AnonXmous' type='producer'),
#  <Person(name='Da Internz' type='producer'),
#  <Person(name='DJ Spydr' type='producer'),
#  <Person(name='Dionne Warwick' type='artist'),
#  <Person(name='Jay and the Americans' type='artist'),
#  <Person(name='Breathe' type='artist'),
#  <Person(name='David Glasper' type='songwriter'),
#  <Person(name='Marcus Lillington' type='songwriter'),
#  <Person(name='Ian Spice' type='songwriter'),
#  <Person(name='Michael Delahunty' type='songwriter'),
#  <Person(name='Helen Reddy' type='artist'),
#  <Person(name='Five' type='artist'),
#  <Person(name='Average White Band' type='artist'),
#  <Person(name='Pharrell Williams' type='artist'),
#  <Person(name='Sheryl Crow' type='artist'),
#  <Person(name='Sheryl Crow' type='songwriter'),
#  <Person(name='Jeff Trott' type='songwriter'),
#  <Person(name='Backstreet Boys' type='artist'),
#  <Person(name='Fleetwood Mac' type='artist'),
#  <Person(name='Bobby Bare' type='artist'),
#  <Person(name='Edward Bear' type='artist'),
#  <Person(name='One Direction' type='artist'),
#  <Person(name='Julian Bunetta' type='songwriter'),
#  <Person(name='Jamie Scott' type='songwriter'),
#  <Person(name='John Ryan' type='songwriter'),
#  <Person(name='Louis Tomlinson' type='songwriter'),
#  <Person(name='Liam Payne' type='songwriter'),
#  <Person(name='Niall Horan' type='songwriter'),
#  <Person(name='Harry Styles' type='songwriter'),
#  <Person(name='Zayn Malik' type='songwriter'),
#  <Person(name='Julian Bunetta' type='producer'),
#  <Person(name='John Ryan' type='producer'),
#  <Person(name='Natalie Cole' type='artist'),
#  <Person(name='Paul McCartney' type='artist'),
#  <Person(name='Michael Jackson' type='artist'),
#  <Person(name='Paul McCartney' type='songwriter'),
#  <Person(name='Michael Jackson' type='songwriter'),
#  <Person(name='Culture Club' type='artist'),
#  <Person(name='Kool & the Gang' type='artist'),
#  <Person(name='Michael Jackson' type='artist'),
#  <Person(name='Michael Jackson' type='producer'),
#  <Person(name='Bruce Swedien (co-producer)' type='producer'),
#  <Person(name='Stray Cats' type='artist'),
#  <Person(name='Whitney Houston' type='artist'),
#  ...]

# %%
session.add_all(ppl)

# %%
session.commit()

# %%
pd.read_sql_table('people',engine)
# Out:
#           id     song_id       ptype            name                   url  \
# 0          1  0005648762      artist    Hall & Oates  /wiki/Hall_%26_Oates
# 1          2  0005648762  songwriter      Daryl Hall      /wiki/Daryl_Hall
# 2          3  0005648762  songwriter     Janna Allen     /wiki/Janna_Allen
# 3          4  0005648762    producer      Daryl Hall      /wiki/Daryl_Hall
# 4          5  0005648762    producer      John Oates      /wiki/John_Oates
# ...      ...         ...         ...             ...                   ...
# 14825  14826  ffdc78eafb  songwriter      David Ritz      /wiki/David_Ritz
# 14826  14827  ffe5348ef0      artist  Richard Harris  /wiki/Richard_Harris
# 14827  14828  ffe721d2e2      artist          Brandy  /wiki/Brandy_Norwood
# 14828  14829  ffe721d2e2  songwriter    Keith Crouch    /wiki/Keith_Crouch
# 14829  14830  ffe721d2e2  songwriter    Kipper Jones                  None
#
#       order
# 0
# 1
# 2
# 3
# 4
# ...     ...
# 14825
# 14826
# 14827
# 14828
# 14829
#
# [14830 rows x 6 columns]

# %%
q = '''
    select 
        sq.*,
        RANK() over (order by sq.artist_sum desc) as artist_rank,
        RANK() over (order by sq.songwriter_sum desc) as songwriter_rank,
        RANK() over (order by sq.producer_sum desc) as producer_rank
        
       
    from
        (select 
            p.name, 
            count(distinct p.song_id) as song_count,
            sum(case when p.ptype='artist' then 1 else 0 end) as artist_sum,
            sum(case when p.ptype='songwriter' then 1 else 0 end) as songwriter_sum,
            sum(case when p.ptype='producer' then 1 else 0 end) as producer_sum
        from 
            people p
        left join 
            songs s
        on 
            p.song_id = s.id
        group by 
            p.name)
        as sq
        
        order by song_count desc
        limit 10

'''
pd.read_sql_query(q,engine)
# Out:
#               name  song_count  artist_sum  songwriter_sum  producer_sum  \
# 0       Max Martin          74           0              73            61
# 1    Aubrey Graham          40           0              40             0
# 2          Madonna          37          37              30            28
# 3            Drake          37          37               0             0
# 4         Dr. Luke          37           0               5            37
# 5  Lukasz Gottwald          36           0              36             0
# 6      the Beatles          33          33               0             0
# 7  Michael Jackson          33          28              12            10
# 8          Rihanna          31          31               1             0
# 9         Babyface          30           5              11            22
#
#    artist_rank  songwriter_rank  producer_rank
# 0         2199                1              1
# 1         2199                2           1502
# 2            1                4              3
# 3            1             3674           1502
# 4         2199              160              2
# 5         2199                3           1502
# 6            3             3674           1502
# 7            5               37             26
# 8            4             1081           1502
# 9          208               42              6
