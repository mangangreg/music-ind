# %% [markdown]
# # Imports

# %%
import sys
import requests
import json
from pathlib import Path

import pandas as pd
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm


root = '../..' 
sys.path.append(root)
from src.tools import paths
from src.tools import data_tools as dt

# %% [markdown]
# # Tools

# %%
def gen_id(wiki_url):
    ''' Generate an 8-digit id (int) for based on the unique wikipedia url'''
    return hash(wiki_url) % 10**8

def clean_text(string):
    ''' Clean common cell text from a <td> tag '''
    return string.replace('\xa0', ' ').replace('\n',' ').strip()

def missing_link(name, soup):
    ''' Find a hpyerlink for a given name '''
    if soup.find('a', text=name):
        return soup.find('a', text=name).attrs.get('href')
    else:
        return None

def get_hyper_list(td, soup):
    '''
        Extract names and URLs from horizontal lists of hyperlinks
        
        Inputs:
            td (bs4 tag)
    '''
    result_list = []
    if not td.find('ul'):
        return [{'name': td.text, 'url':None, 'order': 0}]
    else:
        result_list = []
        for i, li in enumerate(td.find_all('li')):
            name = li.text
            url = li.find('a').attrs.get('href') if li.find('a') else missing_link(name, soup)
            result_list.append({'name': name, 'url': url, 'order': i})
            
        return result_list

# %% [markdown]
# # Starting point
# The List of Billboard Hot 100 top-ten singles

# %%
url_list_of_lists = 'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles'
wiki_base_url = 'http://en.wikipedia.org'

# %%
soup = BeautifulSoup(requests.get(url_list_of_lists).content, 'html.parser')
table = soup.select('#Top-ten_singles_by_year')[0].parent.next_sibling.next_sibling
a_tags = table.findAll('a')

# %%
year_links = [wiki_base_url + link.attrs['href'] for link in a_tags]
year_links
# Out:
# ['http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1958',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1959',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1960',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1961',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1962',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1963',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1964',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1965',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1966',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1967',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1968',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1969',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1970',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1971',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1972',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1973',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1974',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1975',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1976',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1977',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1978',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1979',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1980',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1981',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1982',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1983',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1984',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1985',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1986',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1987',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1988',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1989',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1990',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1991',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1992',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1993',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1994',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1995',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1996',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1997',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1998',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_1999',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2000',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2001',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2002',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2003',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2004',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2005',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2006',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2007',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2008',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2009',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2010',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2011',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2012',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2013',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2014',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2015',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2016',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2017',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2018',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2019',
#  'http://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2020']

# %% [markdown]
# # Year page

# %%
def pull_year_page_table(yp_url, out=True, write_path='../../data/wiki-top-10/'):
    
    def tidy_cell(cell, col=None, year=None):
        cell_text = clean_text(cell.text)
        if col in ['entry_date', 'peak_date']:
            cell_text += f' {year}'
        return cell_text

    # Get year from url
    year = yp_url.split('_')[-1]
    
    # Get html from wikipedia
    soup = BeautifulSoup(requests.get(yp_url).content, 'html.parser')
    
    # Assuming it's always the first table
    if not soup.select('table.wikitable'):
        return
    table = soup.select('table.wikitable')[0]
    n_cols = len(table.find('tr').find_all('th'))

    rowspan_fix = []
    output_rows=[]
    
    for i, row in enumerate(table.find_all('tr')):
        output_row = []
        
        for j, cell in enumerate(row.find_all('td')):
            rowspan = cell.attrs.get('rowspan')
            if rowspan:
                rowspan_fix += [(k,j, cell) for k in range(i+1, i+int(rowspan))]

            output_row.append(cell)
        output_rows.append(output_row)

    for (i,j,cell) in rowspan_fix:
        output_rows[i].insert(j, cell)

    # Build table of tag elelement cells
    df = pd.DataFrame(output_rows)
    df = df[df.columns[:6]].copy() #Drop ref column if it's there
    df.columns = ['entry_date', 'single', 'artist', 'peak', 'peak_date', 'weeks_in_top']
    df.dropna(inplace=True)


    # Tidy up cells, extract data
    for col in [x for x in df.columns if x!='single']:
        df[col] = df[col].apply(lambda x: tidy_cell(x, col, year))

    df['single_url'] = df.single.apply(lambda x: x.find('a').attrs['href']  if x.find('a') else None)
    df.single = df.single.apply(lambda x: tidy_cell(x))
    
    # Write table
    if out:
        df.to_csv(f'{write_path}{year}.csv',index=False)
    return df

# %%
for yl in year_links:
    pull_year_page_table(yl)

# %%
df = pull_year_page_table(year_links[-2])
df
# Out:
#                 entry_date                                        single  \
# 2   December 30(2017) 2019          "All I Want For Christmas Is You"[U]
# 3          October 20 2019                                  "Shallow"[C]
# 4          October 20 2019                                "Happier" (#6)
# 5          November 3 2019                      "Sunflower" (#2)[J][Q] ◁
# 6         November 10 2019                             "Without Me" (#3)
# 7         November 24 2019                                  "High Hopes"
# 9           January 5 2019        "Rockin' Around the Christmas Tree"[U]
# 10         January 19 2019                                 "Eastside"[B]
# 11         January 26 2019                                    "Wow" (#5)
# 12         February 2 2019                              "7 Rings" (#7) ◁
# 13         February 9 2019                          "Middle Child"[C][H]
# 14        February 23 2019  "Break Up with Your Girlfriend, I'm Bored" ◁
# 15            March 2 2019                              "Please Me"[D] ◁
# 16            March 9 2019                                 "Thotiana"[F]
# 17           March 16 2019                              "Sucker" (#10) ◁
# 18           April 13 2019                       "Old Town Road" (#1)[R]
# 19           April 13 2019                           "Bad Guy" (#4)[G] ◁
# 20           April 20 2019                                      "Better"
# 21           April 27 2019                  "Dancing with a Stranger"[I]
# 22           April 27 2019                              "Boy with Luv" ◁
# 23              May 4 2019                                "Talk" (#8)[I]
# 24             May 11 2019                                         "Me!"
# 25             May 18 2019                 "If I Can't Have You"[L][N] ◁
# 26             May 18 2019                                  "Homicide" ◁
# 27             May 25 2019                              "I Don't Care" ◁
# 28             June 1 2019                            "Sweet but Psycho"
# 29             June 8 2019                                        "Suge"
# 30            June 22 2019                         "No Guidance"[K][M] ◁
# 31            June 29 2019                  "You Need to Calm Down"[O] ◁
# 32            June 29 2019                        "Money in the Grave" ◁
# 33             July 6 2019                                  "Señorita" ◁
# 34            July 13 2019                                 "Truth Hurts"
# 35            July 20 2019                               "Goodbyes"[P] ◁
# 36          August 10 2019                                      "Ransom"
# 37          August 17 2019                                 "Boyfriend" ◁
# 38        September 7 2019                                       "Lover"
# 39       September 14 2019                                   "Circles" ◁
# 40       September 21 2019                        "Take What You Want" ◁
# 41       September 21 2019                           "Someone You Loved"
# 42       September 28 2019                                      "Panini"
# 43         October 19 2019                       "Highest in the Room" ◁
# 44         October 19 2019                        "10,000 Hours"[S][T] ◁
# 45         October 26 2019                                      "Bandit"
# 46         November 9 2019                         "Lose You to Love Me"
# 47         November 9 2019                                "Good as Hell"
# 48         November 9 2019                                "Follow God" ◁
# 49        November 30 2019                         "Everything I Wanted"
# 50         December 7 2019                                     "Roxanne"
# 51        December 14 2019                                   "Heartless"
# 11           24                       /wiki/Wow_(Post_Malone_song)
# 12           16                                      /wiki/7_Rings
# 13           10                  /wiki/Middle_Child_(J._Cole_song)
# 14            2   /wiki/Break_Up_with_Your_Girlfriend,_I%27m_Bored
# 15            8                                    /wiki/Please_Me
# 16            2                                     /wiki/Thotiana
# 17           22                                /wiki/Sucker_(song)
# 18           26                                /wiki/Old_Town_Road
# 19           30                 /wiki/Bad_Guy_(Billie_Eilish_song)
# 20            1                         /wiki/Better_(Khalid_song)
# 21            8                      /wiki/Dancing_with_a_Stranger
# 22            1                                 /wiki/Boy_with_Luv
# 23           19                           /wiki/Talk_(Khalid_song)
# 24            4                                          /wiki/Me!
# 25            4    /wiki/If_I_Can%27t_Have_You_(Shawn_Mendes_song)
# 26            1                              /wiki/Homicide_(song)
# 27           17  /wiki/I_Don%27t_Care_(Ed_Sheeran_and_Justin_Bi...
# 28            3                             /wiki/Sweet_but_Psycho
# 29            7                                  /wiki/Suge_(song)
# 30           23                                  /wiki/No_Guidance
# 31            2                        /wiki/You_Need_to_Calm_Down
# 32            2                           /wiki/Money_in_the_Grave
# 33           23  /wiki/Se%C3%B1orita_(Shawn_Mendes_and_Camila_C...
# 34           22                           /wiki/Truth_Hurts_(song)
# 35           12                  /wiki/Goodbyes_(Post_Malone_song)
# 36           13                      /wiki/Ransom_(Lil_Tecca_song)
# 37            1  /wiki/Boyfriend_(Ariana_Grande_and_Social_Hous...
# 38            1                    /wiki/Lover_(Taylor_Swift_song)
# 39           39                   /wiki/Circles_(Post_Malone_song)
# 40            1                           /wiki/Take_What_You_Want
# 41           27                            /wiki/Someone_You_Loved
# 42            9                                /wiki/Panini_(song)
# 43            4                          /wiki/Highest_in_the_Room
# 44           14                          /wiki/10,000_Hours_(song)
# 45            1                                /wiki/Bandit_(song)
# 46           10                          /wiki/Lose_You_to_Love_Me
# 47           11                                 /wiki/Good_as_Hell
# 48            1                                   /wiki/Follow_God
# 49            8     /wiki/Everything_I_Wanted_(Billie_Eilish_song)
# 50           18                /wiki/Roxanne_(Arizona_Zervas_song)
# 51            2                  /wiki/Heartless_(The_Weeknd_song)
# 52            1                          /wiki/Futsal_Shuffle_2020

# %% [markdown]
# # Song page

# %%
test_url = df.single_url.iloc[:5]
test_url
# Out:
# 2                /wiki/All_I_Want_For_Christmas_Is_You
# 3    /wiki/Shallow_(Lady_Gaga_and_Bradley_Cooper_song)
# 4         /wiki/Happier_(Marshmello_and_Bastille_song)
# 5      /wiki/Sunflower_(Post_Malone_and_Swae_Lee_song)
# 6                       /wiki/Without_Me_(Halsey_song)
# Name: single_url, dtype: object

# %%
def pull_song_page_info(sp_url, out=True, write_path=paths.DATA_PATH/'songs'):
    '''
        Pull all information about a song from a wikipedia 'song page'
        Inputs:
            - sp_url (str): a song page url, a relative url (/wiki/...) to a song page
            - out (bool): whether to output the file
            - write_path (str): the path to write the file to if out is True
        Outputs:
            Dictionary of song data
    '''
    try:
        # Generate id
        song_id = gen_song_id(sp_url)

        # Get page html
        soup = BeautifulSoup(requests.get(wiki_base_url + sp_url).content, 'html.parser')
        table = soup.select('table.infobox')[0]

        song_data = {'id': song_id}
        song_data['title'] = table.find('tr').text.strip('"')
        song_data['url'] = sp_url

        # Loop through rows (tr) and identify by heading (th)
        for row in table.find_all('tr'):
            th = row.find('th')
            if th:
                # Artists
                if th.text.startswith('Single by'):
                    links = row.find_all('a')
                    if len(links)==1:
                        song_data.update({'artist':row.text.split('Single by ')[1], 'url':None})
                    else:
                        song_data['artists'] =[{'artist':artist.text, 
                                                'url':artist.attrs['href'], 
                                                'order':i} 
                                               for i, artist in enumerate(links[1:])]
                # Release Date
                elif th.text.startswith('Released'):
                    song_data.update({'release_date': clean_text(row.find('td').text)})

                # Genres
                elif th.text.startswith('Genre'):
                    song_data['genres'] = [clean_text(x.text) for x in row.find('td').find_all('a') if not re.match(re_ref,x.text)]

                # Length
                elif th.text.startswith('Length'):
                    song_data.update({'length': clean_text(row.find('td').text)})

                # Songwriters
                elif th.text.startswith('Songwriter'):
                    song_data['songwriters'] = get_hyper_list(row.find('td'), soup)

                # Producers
                elif th.text.startswith('Producer'):
                    song_data['producers'] = get_hyper_list(row.find('td'), soup)
    
        if out:
            with open(write_path/f'{song_id}.json', 'w') as wfile:
                json.dump(song_data, wfile)
            
        return song_data
    
    except IndexError:
        print(sp_url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-df7876985360> in <module>()
# ----> 1 def pull_song_page_info(sp_url, out=True, write_path=paths.DATA_PATH/'songs'):
#       2     '''
#       3         Pull all information about a song from a wikipedia 'song page'
#       4         Inputs:
#       5             - sp_url (str): a song page url, a relative url (/wiki/...) to a song page
#
# AttributeError: module 'src.tools.paths' has no attribute 'DATA_PATH'

# %%
pull_song_page_info(test_url.iloc[2], True)
# Out:
# {'artists': [{'artist': 'Marshmello', 'order': 0, 'url': '/wiki/Marshmello'},
#   {'artist': 'Bastille', 'order': 1, 'url': '/wiki/Bastille_(band)'}],
#  'genres': ['Dance-pop'],
#  'id': 77162175,
#  'length': '3:34',
#  'producers': [{'name': 'Marshmello', 'url': None}],
#  'release_date': 'August 17, 2018 (2018-08-17)',
#  'songwriters': [{'name': 'Christopher Comstock', 'url': '/wiki/Marshmello'},
#   {'name': 'Dan Smith', 'url': '/wiki/Dan_Smith_(singer)'},
#   {'name': 'Steve Mac', 'url': '/wiki/Steve_Mac'}],
#  'title': 'Happier'}

# %%
df.single_url.apply(lambda url: pull_song_page_info(url))
# Out:
# 2     {'id': 67299063, 'title': 'All I Want for Chri...
# 3     {'id': 5946564, 'title': 'Shallow', 'url': '/w...
# 4     {'id': 77162175, 'title': 'Happier', 'url': '/...
# 5     {'id': 12497455, 'title': 'Sunflower', 'url': ...
# 6     {'id': 53890801, 'title': 'Without Me', 'url':...
# 7     {'id': 49790729, 'title': 'High Hopes', 'url':...
# 9     {'id': 27265974, 'title': 'Rockin' Around the ...
# 10    {'id': 90355098, 'title': 'Eastside', 'url': '...
# 11    {'id': 6130013, 'title': 'Wow.', 'url': '/wiki...
# 12    {'id': 4461425, 'title': '7 Rings', 'url': '/w...
# 13    {'id': 18979570, 'title': 'Middle Child', 'url...
# 14    {'id': 80016038, 'title': 'Break Up with Your ...
# 15    {'id': 11731290, 'title': 'Please Me', 'url': ...
# 16    {'id': 84218161, 'title': 'Thotiana', 'url': '...
# 17    {'id': 97778190, 'title': 'Sucker', 'url': '/w...
# 18    {'id': 60422908, 'title': 'Old Town Road', 'ur...
# 19    {'id': 13736376, 'title': 'Bad Guy', 'url': '/...
# 20    {'id': 82367964, 'title': 'Better', 'url': '/w...
# 21    {'id': 8681010, 'title': 'Dancing with a Stran...
# 22    {'id': 65767323, 'title': 'Boy with Luv', 'url...
# 23    {'id': 19292924, 'title': 'Talk', 'url': '/wik...
# 24    {'id': 90984281, 'title': 'Me!', 'url': '/wiki...
# 25    {'id': 14558672, 'title': 'If I Can't Have You...
# 26    {'id': 98667084, 'title': 'Homicide', 'url': '...
# 27    {'id': 89252462, 'title': 'I Don't Care', 'url...
# 28    {'id': 17397613, 'title': 'Sweet but Psycho', ...
# 29    {'id': 64267869, 'title': 'Suge', 'url': '/wik...
# 30    {'id': 80584227, 'title': 'No Guidance', 'url'...
# 31    {'id': 53605876, 'title': 'You Need to Calm Do...
# 32    {'id': 95652930, 'title': 'The Best in the Wor...
# 33    {'id': 72965531, 'title': 'Señorita', 'url': '...
# 34    {'id': 20007765, 'title': 'Truth Hurts', 'url'...
# 35    {'id': 42448484, 'title': 'Goodbyes', 'url': '...
# 36    {'id': 11022441, 'title': 'Ransom', 'url': '/w...
# 37    {'id': 23068890, 'title': 'Boyfriend', 'url': ...
# 38    {'id': 43023752, 'title': 'Lover', 'url': '/wi...
# 39    {'id': 41930197, 'title': 'Circles', 'url': '/...
# 40    {'id': 98146605, 'title': 'Take What You Want'...
# 41    {'id': 11785515, 'title': 'Someone You Loved',...
# 42    {'id': 81058939, 'title': 'Panini', 'url': '/w...
# 43    {'id': 88464997, 'title': 'Highest in the Room...
# 44    {'id': 63587066, 'title': '10,000 Hours', 'url...
# 45    {'id': 56113991, 'title': 'Bandit', 'url': '/w...
# 46    {'id': 31329164, 'title': 'Lose You to Love Me...
# 47    {'id': 94929658, 'title': 'Good as Hell', 'url...
# 48    {'id': 66921307, 'title': 'Follow God', 'url':...
# 49    {'id': 69190510, 'title': 'Everything I Wanted...
# 50    {'id': 61316978, 'title': 'Roxanne', 'url': '/...
# 51    {'id': 19372734, 'title': 'Heartless', 'url': ...
# 52    {'id': 24797159, 'title': 'Futsal Shuffle 2020...
# Name: single_url, dtype: object

# %%
df.single_url.apply(lambda url: gen_id(url))
# Out:
# 2     67299063
# 3      5946564
# 4     77162175
# 5     12497455
# 6     53890801
# 7     49790729
# 9     27265974
# 10    90355098
# 11     6130013
# 12     4461425
# 13    18979570
# 14    80016038
# 15    11731290
# 16    84218161
# 17    97778190
# 18    60422908
# 19    13736376
# 20    82367964
# 21     8681010
# 22    65767323
# 23    19292924
# 24    90984281
# 25    14558672
# 26    98667084
# 27    89252462
# 28    17397613
# 29    64267869
# 30    80584227
# 31    53605876
# 32    95652930
# 33    72965531
# 34    20007765
# 35    42448484
# 36    11022441
# 37    23068890
# 38    43023752
# 39    41930197
# 40    98146605
# 41    11785515
# 42    81058939
# 43    88464997
# 44    63587066
# 45    56113991
# 46    31329164
# 47    94929658
# 48    66921307
# 49    69190510
# 50    61316978
# 51    19372734
# 52    24797159
# Name: single_url, dtype: int64

# %%
pd.read_csv(list((settings.DATA_PATH/'wiki-top-10/').iterdir())[0],usecols=['single_url'])
# Out:
#                                            single_url
# 0                              /wiki/Poor_Little_Fool
# 1                   /wiki/Patricia_(Perez_Prado_song)
# 2                          /wiki/Splish_Splash_(song)
# 3                             /wiki/Hard_Headed_Woman
# 4                   /wiki/When_(The_Kalin_Twins_song)
# 5                               /wiki/Rebel_%27Rouser
# 6                                    /wiki/Yakety_Yak
# 7                                  /wiki/My_True_Love
# 8                      /wiki/Willie_and_the_Hand_Jive
# 9               /wiki/Fever_(Little_Willie_John_song)
# 10                                /wiki/Volare_(song)
# 11            /wiki/Just_a_Dream_(Jimmy_Clanton_song)
# 12              /wiki/Little_Star_(The_Elegants_song)
# 13                              /wiki/Bird_Dog_(song)
# 14                         /wiki/Born_Too_Late_(song)
# 15                          /wiki/Ginger_Bread_(song)
# 16                       /wiki/Are_You_Really_Mine%3F
# 17                       /wiki/Rockin%27_Robin_(song)
# 18                               /wiki/Western_Movies
# 19                /wiki/It%27s_All_in_the_Game_(song)
# 20                           /wiki/Tears_on_My_Pillow
# 21                              /wiki/Susie_Darlin%27
# 22                        /wiki/Devoted_to_You_(song)
# 23                             /wiki/Summertime_Blues
# 24                                     /wiki/Near_You
# 25                           /wiki/Tea_for_Two_(song)
# 26                    /wiki/The_End_(Earl_Grant_song)
# 27                         /wiki/Topsy_(instrumental)
# 28                     /wiki/It%27s_Only_Make_Believe
# 29                            /wiki/Tom_Dooley_(song)
# 30                        /wiki/Chantilly_Lace_(song)
# 31                   /wiki/To_Know_Him_Is_to_Love_Him
# 32          /wiki/I_Got_a_Feeling_(Ricky_Nelson_song)
# 33                             /wiki/Beep_Beep_(song)
# 34                                /wiki/Lonesome_Town
# 35                             /wiki/Queen_of_the_Hop
# 36               /wiki/One_Night_(Elvis_Presley_song)
# 37                                  /wiki/I_Got_Stung
# 38                              /wiki/Problems_(song)
# 39  /wiki/The_Chipmunk_Song_(Christmas_Don%27t_Be_...

# %%
len(list((paths.DATA/'songs').glob('*')))
# Out:
# 1838

# %%
song_idx = [int(x.stem) for x in(settings.DATA_PATH/'songs').glob('*')]

for year_csv in tqdm((settings.DATA_PATH/'wiki-top-10/').iterdir(), total=len(list((settings.DATA_PATH/'wiki-top-10/').glob('*'))) ):
    df = pd.read_csv(year_csv, usecols=['single_url'])
    for j, sp_url in df[df.single_url.notna()].single_url.iteritems():
        if gen_id(sp_url) not in song_idx:
            pull_song_page_info(sp_url)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=63.0), HTML(value='')))
# /wiki/Are_You_Really_Mine%3F
# /wiki/Topsy_(instrumental)
# /wiki/The_All_American_Boy
# /wiki/Tall_Paul
# /wiki/Petite_Fleur
# /wiki/The_Deck_of_Cards
# /wiki/My_Empty_Arms
# /wiki/The_Writing_on_the_Wall_(Adam_Wade_song)
# /wiki/I_Understand_(Just_How_You_Feel)
# /wiki/Tonight_(1956_song)
# /wiki/More_(Theme_from_Mondo_Cane)
# /wiki/GTO_(Ronny_%26_the_Daytonas_song)
# /wiki/The_Clapping_Song
# /wiki/Lara%27s_Theme
# /wiki/Desiderata
# /wiki/Jesu,_Joy_of_Man%27s_Desiring
# /wiki/The_Americans_(commentary)
# /wiki/Nadia%27s_Theme
# /wiki/This_Could_Be_the_Night_(Loverboy_song)
# /wiki/Scream/Childhood
# /wiki/Auld_Lang_Syne
# /wiki/Rain_on_Me
# /wiki/Work_from_Home

# %% [markdown]
# ### jcole

# %%
pull_song_page_info(jcole)
# Out:
# li text ['Jermaine Cole']
# li text ['Allan Felder']
# li text ['Norman Harris']
# li text ['Tyler Williams']
# li text ['T-Minus']
# li text ['Cole']
# {'artists': [{'artist': 'J. Cole', 'order': 0, 'url': '/wiki/J._Cole'}],
#  'genres': ['Hip hop'],
#  'id': 18979570,
#  'length': '3:33',
#  'producers': [{'name': 'T-Minus',
#    'order': 0,
#    'url': '/wiki/T-Minus_(record_producer)'},
#   {'name': 'Cole', 'order': 1, 'url': None}],
#  'release_date': 'January 23, 2019',
#  'songwriters': [{'name': 'Jermaine Cole',
#    'order': 0,
#    'url': '/wiki/Jermaine_Cole'},
#   {'name': 'Allan Felder', 'order': 1, 'url': '/wiki/Allan_Felder'},
#   {'name': 'Norman Harris',
#    'order': 2,
#    'url': '/wiki/Norman_Harris_(musician)'},
#   {'name': 'Tyler Williams',
#    'order': 3,
#    'url': '/wiki/T-Minus_(record_producer)'}],
#  'title': 'Middle Child',
#  'url': '/wiki/Middle_Child_(J._Cole_song)'}

# %% [markdown]
# # Testing

# %%
from importlib import reload
import sys
sys.path.append('..')
from scr import scrape_songpage as ssp

# %%
reload(ssp)
ssp.pull_info("/wiki/Poor_Little_Fool", False)
# Out:
# {'artists': [{'artist': 'Ricky Nelson',
#    'order': 0,
#    'url': '/wiki/Ricky_Nelson'}],
#  'genres': ['Country'],
#  'id': 42552041,
#  'length': '2:32',
#  'producers': [{'name': 'Ricky Nelson, Ozzie Nelson, Jimmie Haskell',
#    'order': 0,
#    'url': None}],
#  'release_date': 'June 23, 1958',
#  'songwriters': [{'name': 'Sharon Sheeley', 'order': 0, 'url': None}],
#  'title': 'Poor Little Fool',
#  'url': '/wiki/Poor_Little_Fool'}

# %%
dt.load_charts(2020)
# Out:
#                 entry_date                                         single  \
# 0   December 29(2018) 2020  "It's the Most Wonderful Time of the Year"[A]
# 1           January 5 2020                             "Jingle Bell Rock"
# 2           January 5 2020                        "Holly Jolly Christmas"
# 3         November 16 2020                                     "Memories"
# 4         December 21 2020                              "Dance Monkey"[B]
# 5          January 11 2020                                      "The Box"
# 6          January 18 2020                                      "Yummy" ◁
# 7          January 25 2020                            "Life Is Good"[I] ◁
# 8          February 1 2020                                   "Godzilla" ◁
# 9          February 8 2020                              "Don't Start Now"
# 10        February 29 2020                             "Intentions"[D][I]
# 11        February 29 2020                              "Blinding Lights"
# 12            March 7 2020                                         "On" ◁
# 13           March 14 2020                                "Stupid Love" ◁
# 14           March 21 2020                                 "Baby Pluto" ◁
# 15           March 21 2020                                    "Lo Mein" ◁
# 16           March 21 2020                                "Silly Watch" ◁
# 17           March 28 2020                                    "Adore You"
# 18            April 4 2020                                       "Say So"
